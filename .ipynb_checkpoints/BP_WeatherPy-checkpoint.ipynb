# %%
# %matplotlib notebook

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint

# Import API key
import BP_api_keys

from BP_api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "BP_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
CountryList = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    Country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code    
    
    if city not in cities:
        cities.append(city)
        CountryList.append(Country)

# Print the city count to confirm sufficient count
print(f'Length of Cities: \n{len(cities)}')
# print(f'\nCities: \n{cities}')

# Create a dictionary of the cities
cities_dic = {"City": cities, "Country": CountryList}

# Create a data frame of the cities
cities_df = pd.DataFrame(cities_dic)
print(f'\nCities Data Frame:')
cities_df.head()
# Out:
# Length of Cities:
# 599
#
# Cities Data Frame:
#            City Country
# 0  punta arenas      cl
# 1      victoria      sc
# 2     orcopampa      pe
# 3        nivala      fi
# 4       rikitea      pf

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = BP_api_keys.api_key

# Starting URL for Weather Map API Call
url = f'http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid={api_key}'

# %%
RowCount = 0

print(f'\nRetrieve Weather Data:')

## TEST NEW FOR LOOP

# for index, row in cities_df.head().iterrows(): ## print 5 cities only during development
for index, row in cities_df.iterrows(): ## print 5 cities only during development
    
    City = row["City"]
    target_url = f'{url}&q={City}' 
#     print({target_url})

    response = requests.get(target_url)
    response_json = response.json()
    
# pprint(response_json)
    
    print(f'{"*"*20}')
    print(f'\nRetrieve city #{RowCount + 1}: {cities_df.loc[index]["City"]}')
    print(f'URL: {target_url}')


    RowCount = RowCount + 1
    
    try:
        cities_df.set_value(index, "Date", response_json["dt"])
        cities_df.set_value(index, "Lat", response_json["coord"]["lat"])
        cities_df.set_value(index, "Lng", response_json["coord"]["lon"])
        cities_df.set_value(index, "Max Temperature (F)", response_json["main"]["temp_max"])
        cities_df.set_value(index, "Humidity", response_json["main"]["humidity"])
        cities_df.set_value(index, "Cloudiness", response_json["clouds"]["all"])
        cities_df.set_value(index, "Wind Speed", response_json["wind"]["speed"])
        
    except:
        print("Exception: Missing data point(s)")
  
    # Perform modulus to print out 100 cities before pausing
    if RowCount % 100 == 0:
        print(f'{"*"*20}')
        print(f'\nPause: 30 seconds\n')
        time.sleep(10)

print(f'{"*"*20}')        
print(f'\nRetrieval of 25 example records complete\n')
print(f'{"*"*20}')
# Out:
# Retrieve Weather Data:
# ********************
#
# Retrieve city #1: punta arenas
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=punta arenas
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ********************
#
# Retrieve city #2: victoria
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=victoria
# ********************
#
# Retrieve city #3: orcopampa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=orcopampa
# ********************
#
# Retrieve city #4: nivala
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nivala
# ********************
#
# Retrieve city #5: rikitea
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rikitea
# ********************
#
# Retrieve city #6: albany
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=albany
# ********************
#
# Retrieve city #7: atuona
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=atuona
# ********************
#
# Retrieve city #8: kerteh
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kerteh
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #9: bredasdorp
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bredasdorp
# ********************
#
# Retrieve city #10: qaanaaq
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=qaanaaq
# ********************
#
# Retrieve city #11: laguna
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=laguna
# ********************
#
# Retrieve city #12: airai
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=airai
# ********************
#
# Retrieve city #13: saint-philippe
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-philippe
# ********************
#
# Retrieve city #14: sorong
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sorong
# ********************
#
# Retrieve city #15: college
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=college
# ********************
#
# Retrieve city #16: port alfred
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port alfred
# ********************
#
# Retrieve city #17: kruisfontein
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kruisfontein
# ********************
#
# Retrieve city #18: katsuura
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=katsuura
# ********************
#
# Retrieve city #19: sorland
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sorland
# ********************
#
# Retrieve city #20: oranjemund
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=oranjemund
# ********************
#
# Retrieve city #21: uruacu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=uruacu
# ********************
#
# Retrieve city #22: clyde river
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=clyde river
# ********************
#
# Retrieve city #23: esperance
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=esperance
# ********************
#
# Retrieve city #24: sioux lookout
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sioux lookout
# ********************
#
# Retrieve city #25: vaini
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaini
# ********************
#
# Retrieve city #26: flinders
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=flinders
# ********************
#
# Retrieve city #27: puerto ayora
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto ayora
# ********************
#
# Retrieve city #28: new norfolk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=new norfolk
# ********************
#
# Retrieve city #29: tuktoyaktuk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuktoyaktuk
# ********************
#
# Retrieve city #30: mar del plata
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mar del plata
# ********************
#
# Retrieve city #31: hermanus
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hermanus
# ********************
#
# Retrieve city #32: karratha
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=karratha
# ********************
#
# Retrieve city #33: taree
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=taree
# ********************
#
# Retrieve city #34: mataura
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mataura
# ********************
#
# Retrieve city #35: warrington
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=warrington
# ********************
#
# Retrieve city #36: alyangula
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=alyangula
# ********************
#
# Retrieve city #37: areia branca
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=areia branca
# ********************
#
# Retrieve city #38: carnarvon
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=carnarvon
# ********************
#
# Retrieve city #39: labytnangi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=labytnangi
# ********************
#
# Retrieve city #40: cayenne
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cayenne
# ********************
#
# Retrieve city #41: pisco
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pisco
# ********************
#
# Retrieve city #42: busselton
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=busselton
# ********************
#
# Retrieve city #43: hamilton
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hamilton
# ********************
#
# Retrieve city #44: saskylakh
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saskylakh
# ********************
#
# Retrieve city #45: bethel
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bethel
# ********************
#
# Retrieve city #46: lompoc
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lompoc
# ********************
#
# Retrieve city #47: nadym
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nadym
# ********************
#
# Retrieve city #48: chokurdakh
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chokurdakh
# ********************
#
# Retrieve city #49: chapais
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chapais
# ********************
#
# Retrieve city #50: griffith
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=griffith
# ********************
#
# Retrieve city #51: hobart
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hobart
# ********************
#
# Retrieve city #52: jamestown
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jamestown
# ********************
#
# Retrieve city #53: codrington
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=codrington
# ********************
#
# Retrieve city #54: mahebourg
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mahebourg
# ********************
#
# Retrieve city #55: pontianak
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pontianak
# ********************
#
# Retrieve city #56: ushuaia
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ushuaia
# ********************
#
# Retrieve city #57: broken hill
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=broken hill
# ********************
#
# Retrieve city #58: norman wells
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=norman wells
# ********************
#
# Retrieve city #59: kieta
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kieta
# ********************
#
# Retrieve city #60: kaitangata
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaitangata
# ********************
#
# Retrieve city #61: bluff
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bluff
# ********************
#
# Retrieve city #62: avarua
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=avarua
# ********************
#
# Retrieve city #63: marawi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=marawi
# ********************
#
# Retrieve city #64: quatre cocos
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=quatre cocos
# ********************
#
# Retrieve city #65: cape town
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cape town
# ********************
#
# Retrieve city #66: yar-sale
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yar-sale
# ********************
#
# Retrieve city #67: taoudenni
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=taoudenni
# ********************
#
# Retrieve city #68: los llanos de aridane
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=los llanos de aridane
# ********************
#
# Retrieve city #69: cabo san lucas
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cabo san lucas
# ********************
#
# Retrieve city #70: taolanaro
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=taolanaro
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #71: khatanga
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=khatanga
# ********************
#
# Retrieve city #72: coxim
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=coxim
# ********************
#
# Retrieve city #73: barrow
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=barrow
# ********************
#
# Retrieve city #74: mallama
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mallama
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #75: atambua
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=atambua
# ********************
#
# Retrieve city #76: satitoa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=satitoa
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #77: samalaeulu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=samalaeulu
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #78: goderich
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=goderich
# ********************
#
# Retrieve city #79: yellowknife
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yellowknife
# ********************
#
# Retrieve city #80: makakilo city
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=makakilo city
# ********************
#
# Retrieve city #81: taburi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=taburi
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #82: cidreira
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cidreira
# ********************
#
# Retrieve city #83: labuhan
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=labuhan
# ********************
#
# Retrieve city #84: birao
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=birao
# ********************
#
# Retrieve city #85: yulara
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yulara
# ********************
#
# Retrieve city #86: faya
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=faya
# ********************
#
# Retrieve city #87: torbay
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=torbay
# ********************
#
# Retrieve city #88: lavrentiya
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lavrentiya
# ********************
#
# Retrieve city #89: belgrade
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=belgrade
# ********************
#
# Retrieve city #90: mys shmidta
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mys shmidta
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #91: hua hin
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hua hin
# ********************
#
# Retrieve city #92: vanavara
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vanavara
# ********************
#
# Retrieve city #93: ati
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ati
# ********************
#
# Retrieve city #94: tiksi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tiksi
# ********************
#
# Retrieve city #95: kapaa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kapaa
# ********************
#
# Retrieve city #96: kavarna
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavarna
# ********************
#
# Retrieve city #97: bandarbeyla
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bandarbeyla
# ********************
#
# Retrieve city #98: mangalia
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mangalia
# ********************
#
# Retrieve city #99: vila franca do campo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila franca do campo
# ********************
#
# Retrieve city #100: tsihombe
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tsihombe
# Exception: Missing data point(s)
# ********************
#
# Pause: 30 seconds
#
# ********************
#
# Retrieve city #101: port elizabeth
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port elizabeth
# ********************
#
# Retrieve city #102: gobabis
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gobabis
# ********************
#
# Retrieve city #103: saint-francois
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-francois
# ********************
#
# Retrieve city #104: thunder bay
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=thunder bay
# ********************
#
# Retrieve city #105: saint-georges
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-georges
# ********************
#
# Retrieve city #106: hilo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hilo
# ********************
#
# Retrieve city #107: taganak
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=taganak
# ********************
#
# Retrieve city #108: batemans bay
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=batemans bay
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-09fbe36e8759> in <module>()
#      10 #     print({target_url})
#      11
# ---> 12     response = requests.get(target_url)
#      13     response_json = response.json()
#      14
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## Data Cleaning

# %%
cities_df.head(20)

# %%
#Check number of values for each column to see if we lost cities in the search 
print(f'\nColumn Counts:')
cities_df.count()

# %%
#Drop columns with missing variables
cities_df = cities_df.dropna()
cities_df.head()

# %%
#Convert "Date" to DATETIME
cities_df['Date'] = pd.to_datetime(cities_df['Date'], unit='s')
cities_df.head()

# %%
# Save Cities Data frame to an output csv file
cities_df.to_csv("Output/BP_Output_cities_df.csv", index = False)

# %% [markdown]
# ## Chart: Temperature (F) vs. Latitude Scatter Plot

# %%
cities_df.plot.scatter(["Lat"], ["Max Temperature (F)"], marker ='o', alpha = 1, grid = True)

# Chart details
plt.title("Termperature (F) v. City Latitude")
plt.xlabel("City Latitude")
plt.ylabel("Max Temp (F)")

# Save an image of the chart and print to screen
plt.savefig("Output/BP_Output_Temperature_vs_CityLatitude_ScatterPlot.png")
plt.show()

# %% [markdown]
# ## Chart: Humidity (%) vs. Latitude

# %%
cities_df.plot.scatter(["Lat"], ["Humidity"], marker ='o', alpha = 1, grid = True)

# Chart details
plt.title("Humidity v. City Latitude")
plt.xlabel("City Latitude")
plt.ylabel("Humidity")

# Save an image of the chart and print to screen
plt.savefig("Output/BP_Output_Humidity_vs_CityLatitude_ScatterPlot.png")
plt.show()

# %% [markdown]
# ## Chart: Cloudiness (%) vs. Latitude

# %%
cities_df.plot.scatter(["Lat"], ["Cloudiness"], marker ='o', alpha = 1, grid = True)

# Chart details
plt.title("Cloudiness v. City Latitude")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness")

# Save an image of the chart and print to screen
plt.savefig("Output/BP_Output_Cloudiness_vs_CityLatitude_ScatterPlot.png")
plt.show()

# %% [markdown]
# ## Chart: Wind Speed (mph) vs. Latitude

# %%
cities_df.plot.scatter(["Lat"], ["Wind Speed"], marker ='o', alpha = 1, grid = True)

# Chart details
plt.title("Wind Speed (MPH) v. City Latitude")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (MPH)")

# Save an image of the chart and print to screen
plt.savefig("Output/BP_Output_WindSpeedMPH_vs_CityLatitude_ScatterPlot.png")
plt.show()
