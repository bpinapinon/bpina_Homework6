# %%
# %matplotlib notebook

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint

# Import API key
import BP_api_keys

from BP_api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "BP_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
CountryList = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    Country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code    
    
    if city not in cities:
        cities.append(city)
        CountryList.append(Country)

# Print the city count to confirm sufficient count
print(f'Length of Cities: \n{len(cities)}')
# print(f'\nCities: \n{cities}')

# Create a dictionary of the cities
cities_dic = {"City": cities, "Country": CountryList}

# Create a data frame of the cities
cities_df = pd.DataFrame(cities_dic)
print(f'\nCities Data Frame:')
cities_df.head()
# Out:
# Length of Cities:
# 638
#
# Cities Data Frame:
#             City Country
# 0  belushya guba      ru
# 1          vaini      to
# 2          airai      pw
# 3    grand haven      us
# 4         utiroa      ki

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = BP_api_keys.api_key

# Starting URL for Weather Map API Call
url = f'http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid={api_key}'

# %%
RowCount = 0

print(f'\nRetrieve Weather Data:')

# for index, row in cities_df.head().iterrows(): ## print 5 cities only during development
for index, row in cities_df.iterrows(): ## print 5 cities only during development
    
    City = row["City"]
    target_url = f'{url}&q={City}' 
#     print({target_url})

    response = requests.get(target_url)
    response_json = response.json()
    
# pprint(response_json)

    print(f'{"*"*20}')
    print(f'\nRetrieve city #{RowCount + 1}: {cities_df.loc[index]["City"]}')
    print(f'URL: {target_url}')


    RowCount = RowCount + 1
    
    try:
        cities_df.set_value(index, "Date", response_json["dt"])
        cities_df.set_value(index, "Lat", response_json["coord"]["lat"])
        cities_df.set_value(index, "Lng", response_json["coord"]["lon"])
        cities_df.set_value(index, "Max Temperature (F)", response_json["main"]["temp_max"])
        cities_df.set_value(index, "Humidity", response_json["main"]["humidity"])
        cities_df.set_value(index, "Cloudiness", response_json["clouds"]["all"])
        cities_df.set_value(index, "Wind Speed", response_json["wind"]["speed"])
        
    except:
        print("Exception: Missing data point(s)")
  
    # Perform modulus to print out 100 cities before pausing
    if RowCount % 100 == 0:
        print(f'{"*"*20}')
        print(f'\nPause: 30 seconds\n')
        time.sleep(30)

print(f'{"*"*20}')        
print(f'\nRetrieval complete\n')
print(f'{"*"*20}')
# Out:
# Retrieve Weather Data:
# ********************
#
# Retrieve city #1: belushya guba
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=belushya guba
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #2: vaini
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaini
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\bpina\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ********************
#
# Retrieve city #3: airai
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=airai
# ********************
#
# Retrieve city #4: grand haven
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=grand haven
# ********************
#
# Retrieve city #5: utiroa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=utiroa
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #6: albany
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=albany
# ********************
#
# Retrieve city #7: ushuaia
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ushuaia
# ********************
#
# Retrieve city #8: jamestown
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jamestown
# ********************
#
# Retrieve city #9: port elizabeth
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port elizabeth
# ********************
#
# Retrieve city #10: san antonio
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=san antonio
# ********************
#
# Retrieve city #11: chuy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chuy
# ********************
#
# Retrieve city #12: atuona
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=atuona
# ********************
#
# Retrieve city #13: mecca
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mecca
# ********************
#
# Retrieve city #14: lavrentiya
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lavrentiya
# ********************
#
# Retrieve city #15: moss point
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=moss point
# ********************
#
# Retrieve city #16: mantua
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mantua
# ********************
#
# Retrieve city #17: zaoyang
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zaoyang
# ********************
#
# Retrieve city #18: longyearbyen
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=longyearbyen
# ********************
#
# Retrieve city #19: vila franca do campo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila franca do campo
# ********************
#
# Retrieve city #20: taolanaro
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=taolanaro
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #21: bluff
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bluff
# ********************
#
# Retrieve city #22: lorengau
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lorengau
# ********************
#
# Retrieve city #23: olinda
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=olinda
# ********************
#
# Retrieve city #24: barentsburg
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=barentsburg
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #25: tumannyy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tumannyy
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #26: mitsamiouli
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mitsamiouli
# ********************
#
# Retrieve city #27: sao filipe
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sao filipe
# ********************
#
# Retrieve city #28: saint-philippe
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-philippe
# ********************
#
# Retrieve city #29: castro
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=castro
# ********************
#
# Retrieve city #30: barrow
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=barrow
# ********************
#
# Retrieve city #31: torbay
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=torbay
# ********************
#
# Retrieve city #32: bilibino
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bilibino
# ********************
#
# Retrieve city #33: ostrovnoy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ostrovnoy
# ********************
#
# Retrieve city #34: alofi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=alofi
# ********************
#
# Retrieve city #35: busselton
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=busselton
# ********************
#
# Retrieve city #36: hobart
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hobart
# ********************
#
# Retrieve city #37: cururupu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cururupu
# ********************
#
# Retrieve city #38: akureyri
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=akureyri
# ********************
#
# Retrieve city #39: haimen
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=haimen
# ********************
#
# Retrieve city #40: saint-denis
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-denis
# ********************
#
# Retrieve city #41: saskylakh
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saskylakh
# ********************
#
# Retrieve city #42: qaanaaq
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=qaanaaq
# ********************
#
# Retrieve city #43: kapaa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kapaa
# ********************
#
# Retrieve city #44: punta arenas
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=punta arenas
# ********************
#
# Retrieve city #45: rikitea
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rikitea
# ********************
#
# Retrieve city #46: bradley
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bradley
# ********************
#
# Retrieve city #47: richards bay
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=richards bay
# ********************
#
# Retrieve city #48: nuevitas
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nuevitas
# ********************
#
# Retrieve city #49: varkkallai
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=varkkallai
# ********************
#
# Retrieve city #50: nizhneyansk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nizhneyansk
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #51: new norfolk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=new norfolk
# ********************
#
# Retrieve city #52: vaitupu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaitupu
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #53: leshukonskoye
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=leshukonskoye
# ********************
#
# Retrieve city #54: mataura
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mataura
# ********************
#
# Retrieve city #55: merauke
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=merauke
# ********************
#
# Retrieve city #56: lufilufi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lufilufi
# ********************
#
# Retrieve city #57: saleaula
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saleaula
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #58: avarua
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=avarua
# ********************
#
# Retrieve city #59: iwaki
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=iwaki
# ********************
#
# Retrieve city #60: mentok
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mentok
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #61: jiddah
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jiddah
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #62: hithadhoo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hithadhoo
# ********************
#
# Retrieve city #63: east london
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=east london
# ********************
#
# Retrieve city #64: cabo san lucas
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cabo san lucas
# ********************
#
# Retrieve city #65: portland
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=portland
# ********************
#
# Retrieve city #66: half moon bay
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=half moon bay
# ********************
#
# Retrieve city #67: samarai
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=samarai
# ********************
#
# Retrieve city #68: lolua
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lolua
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #69: rantepao
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rantepao
# ********************
#
# Retrieve city #70: tuktoyaktuk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuktoyaktuk
# ********************
#
# Retrieve city #71: tiksi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tiksi
# ********************
#
# Retrieve city #72: hihifo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hihifo
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #73: victoria
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=victoria
# ********************
#
# Retrieve city #74: kruisfontein
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kruisfontein
# ********************
#
# Retrieve city #75: berezovka
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=berezovka
# ********************
#
# Retrieve city #76: hermanus
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hermanus
# ********************
#
# Retrieve city #77: komsomolskiy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=komsomolskiy
# ********************
#
# Retrieve city #78: douentza
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=douentza
# ********************
#
# Retrieve city #79: ponta do sol
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ponta do sol
# ********************
#
# Retrieve city #80: yabrud
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yabrud
# ********************
#
# Retrieve city #81: kholodnyy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kholodnyy
# ********************
#
# Retrieve city #82: batemans bay
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=batemans bay
# ********************
#
# Retrieve city #83: kyaikkami
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kyaikkami
# ********************
#
# Retrieve city #84: iquique
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=iquique
# ********************
#
# Retrieve city #85: avera
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=avera
# ********************
#
# Retrieve city #86: ouargaye
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ouargaye
# ********************
#
# Retrieve city #87: kostino
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kostino
# ********************
#
# Retrieve city #88: georgetown
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=georgetown
# ********************
#
# Retrieve city #89: indiana
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=indiana
# ********************
#
# Retrieve city #90: zhigansk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhigansk
# ********************
#
# Retrieve city #91: nikolskoye
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nikolskoye
# ********************
#
# Retrieve city #92: attawapiskat
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=attawapiskat
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #93: karratha
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=karratha
# ********************
#
# Retrieve city #94: harper
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=harper
# ********************
#
# Retrieve city #95: flinders
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=flinders
# ********************
#
# Retrieve city #96: khatanga
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=khatanga
# ********************
#
# Retrieve city #97: hilo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hilo
# ********************
#
# Retrieve city #98: cabedelo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cabedelo
# ********************
#
# Retrieve city #99: cape town
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cape town
# ********************
#
# Retrieve city #100: port alfred
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port alfred
# ********************
#
# Pause: 30 seconds
#
# ********************
#
# Retrieve city #101: mogadishu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mogadishu
# ********************
#
# Retrieve city #102: tuatapere
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tuatapere
# ********************
#
# Retrieve city #103: labuhan
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=labuhan
# ********************
#
# Retrieve city #104: mayo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mayo
# ********************
#
# Retrieve city #105: norman wells
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=norman wells
# ********************
#
# Retrieve city #106: gazojak
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gazojak
# ********************
#
# Retrieve city #107: awjilah
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=awjilah
# ********************
#
# Retrieve city #108: burica
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=burica
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #109: bengkulu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bengkulu
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #110: tasiilaq
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tasiilaq
# ********************
#
# Retrieve city #111: belmonte
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=belmonte
# ********************
#
# Retrieve city #112: narsaq
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=narsaq
# ********************
#
# Retrieve city #113: moyale
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=moyale
# ********************
#
# Retrieve city #114: provideniya
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=provideniya
# ********************
#
# Retrieve city #115: lewisporte
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lewisporte
# ********************
#
# Retrieve city #116: gravdal
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gravdal
# ********************
#
# Retrieve city #117: vila velha
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vila velha
# ********************
#
# Retrieve city #118: onguday
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=onguday
# ********************
#
# Retrieve city #119: fortuna
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=fortuna
# ********************
#
# Retrieve city #120: tezu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tezu
# ********************
#
# Retrieve city #121: kaitangata
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kaitangata
# ********************
#
# Retrieve city #122: basco
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=basco
# ********************
#
# Retrieve city #123: dikson
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dikson
# ********************
#
# Retrieve city #124: jinxiang
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jinxiang
# ********************
#
# Retrieve city #125: illoqqortoormiut
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=illoqqortoormiut
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #126: clyde river
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=clyde river
# ********************
#
# Retrieve city #127: samarinda
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=samarinda
# ********************
#
# Retrieve city #128: bredasdorp
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bredasdorp
# ********************
#
# Retrieve city #129: snasa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=snasa
# ********************
#
# Retrieve city #130: ribas do rio pardo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ribas do rio pardo
# ********************
#
# Retrieve city #131: mount isa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mount isa
# ********************
#
# Retrieve city #132: namatanai
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=namatanai
# ********************
#
# Retrieve city #133: madingou
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=madingou
# ********************
#
# Retrieve city #134: bathsheba
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bathsheba
# ********************
#
# Retrieve city #135: ruston
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ruston
# ********************
#
# Retrieve city #136: port hardy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port hardy
# ********************
#
# Retrieve city #137: yining
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yining
# ********************
#
# Retrieve city #138: khani
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=khani
# ********************
#
# Retrieve city #139: nam tha
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nam tha
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #140: lagoa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lagoa
# ********************
#
# Retrieve city #141: mar del plata
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mar del plata
# ********************
#
# Retrieve city #142: buariki
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=buariki
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #143: kolpny
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kolpny
# ********************
#
# Retrieve city #144: burgeo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=burgeo
# ********************
#
# Retrieve city #145: puerto ayora
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=puerto ayora
# ********************
#
# Retrieve city #146: sorvag
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sorvag
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #147: souillac
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=souillac
# ********************
#
# Retrieve city #148: trstena
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=trstena
# ********************
#
# Retrieve city #149: karaul
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=karaul
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #150: graaff-reinet
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=graaff-reinet
# ********************
#
# Retrieve city #151: cayenne
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cayenne
# ********************
#
# Retrieve city #152: atlantic city
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=atlantic city
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #153: aklavik
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=aklavik
# ********************
#
# Retrieve city #154: ancud
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ancud
# ********************
#
# Retrieve city #155: lebu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lebu
# ********************
#
# Retrieve city #156: lagunas
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lagunas
# ********************
#
# Retrieve city #157: nushki
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nushki
# ********************
#
# Retrieve city #158: olafsvik
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=olafsvik
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #159: cherskiy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cherskiy
# ********************
#
# Retrieve city #160: muroto
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=muroto
# ********************
#
# Retrieve city #161: primorsk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=primorsk
# ********************
#
# Retrieve city #162: bonthe
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bonthe
# ********************
#
# Retrieve city #163: broome
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=broome
# ********************
#
# Retrieve city #164: saint-joseph
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-joseph
# ********************
#
# Retrieve city #165: zhanaozen
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhanaozen
# ********************
#
# Retrieve city #166: shelburne
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=shelburne
# ********************
#
# Retrieve city #167: gonbad-e qabus
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gonbad-e qabus
# ********************
#
# Retrieve city #168: katsuura
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=katsuura
# ********************
#
# Retrieve city #169: kavieng
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kavieng
# ********************
#
# Retrieve city #170: areosa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=areosa
# ********************
#
# Retrieve city #171: coihaique
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=coihaique
# ********************
#
# Retrieve city #172: charters towers
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=charters towers
# ********************
#
# Retrieve city #173: upernavik
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=upernavik
# ********************
#
# Retrieve city #174: naze
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=naze
# ********************
#
# Retrieve city #175: mackay
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mackay
# ********************
#
# Retrieve city #176: grande prairie
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=grande prairie
# ********************
#
# Retrieve city #177: payyannur
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=payyannur
# ********************
#
# Retrieve city #178: arraial do cabo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=arraial do cabo
# ********************
#
# Retrieve city #179: kathmandu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kathmandu
# ********************
#
# Retrieve city #180: igrim
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=igrim
# ********************
#
# Retrieve city #181: carutapera
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=carutapera
# ********************
#
# Retrieve city #182: el penon
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=el penon
# ********************
#
# Retrieve city #183: yellowknife
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yellowknife
# ********************
#
# Retrieve city #184: carnarvon
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=carnarvon
# ********************
#
# Retrieve city #185: san andres
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=san andres
# ********************
#
# Retrieve city #186: butaritari
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=butaritari
# ********************
#
# Retrieve city #187: kouroussa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kouroussa
# ********************
#
# Retrieve city #188: wakkanai
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=wakkanai
# ********************
#
# Retrieve city #189: kodiak
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kodiak
# ********************
#
# Retrieve city #190: anadyr
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=anadyr
# ********************
#
# Retrieve city #191: kudahuvadhoo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kudahuvadhoo
# ********************
#
# Retrieve city #192: samusu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=samusu
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #193: verkhnyaya inta
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=verkhnyaya inta
# ********************
#
# Retrieve city #194: muisne
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=muisne
# ********************
#
# Retrieve city #195: husavik
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=husavik
# ********************
#
# Retrieve city #196: kamaishi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kamaishi
# ********************
#
# Retrieve city #197: coahuayana
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=coahuayana
# ********************
#
# Retrieve city #198: lithakia
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lithakia
# ********************
#
# Retrieve city #199: marcona
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=marcona
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #200: humaita
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=humaita
# ********************
#
# Pause: 30 seconds
#
# ********************
#
# Retrieve city #201: saint george
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint george
# ********************
#
# Retrieve city #202: asfi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=asfi
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #203: marzuq
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=marzuq
# ********************
#
# Retrieve city #204: anito
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=anito
# ********************
#
# Retrieve city #205: ust-maya
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ust-maya
# ********************
#
# Retrieve city #206: alta
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=alta
# ********************
#
# Retrieve city #207: kuche
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kuche
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #208: chiang mai
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chiang mai
# ********************
#
# Retrieve city #209: show low
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=show low
# ********************
#
# Retrieve city #210: westport
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=westport
# ********************
#
# Retrieve city #211: mahebourg
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mahebourg
# ********************
#
# Retrieve city #212: jiaocheng
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jiaocheng
# ********************
#
# Retrieve city #213: jian
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jian
# ********************
#
# Retrieve city #214: koumac
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=koumac
# ********************
#
# Retrieve city #215: lasa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lasa
# ********************
#
# Retrieve city #216: pierre
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pierre
# ********************
#
# Retrieve city #217: dingle
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dingle
# ********************
#
# Retrieve city #218: inyonga
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=inyonga
# ********************
#
# Retrieve city #219: kon tum
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kon tum
# ********************
#
# Retrieve city #220: klaksvik
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=klaksvik
# ********************
#
# Retrieve city #221: dali
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=dali
# ********************
#
# Retrieve city #222: tsihombe
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tsihombe
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #223: chumikan
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chumikan
# ********************
#
# Retrieve city #224: pisco
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pisco
# ********************
#
# Retrieve city #225: kachiry
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kachiry
# ********************
#
# Retrieve city #226: nago
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nago
# ********************
#
# Retrieve city #227: loei
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=loei
# ********************
#
# Retrieve city #228: wukari
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=wukari
# ********************
#
# Retrieve city #229: udhampur
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=udhampur
# ********************
#
# Retrieve city #230: itarema
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=itarema
# ********************
#
# Retrieve city #231: aykhal
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=aykhal
# ********************
#
# Retrieve city #232: phan thiet
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=phan thiet
# ********************
#
# Retrieve city #233: saint-pierre
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=saint-pierre
# ********************
#
# Retrieve city #234: bushehr
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bushehr
# ********************
#
# Retrieve city #235: isangel
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=isangel
# ********************
#
# Retrieve city #236: inhambane
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=inhambane
# ********************
#
# Retrieve city #237: hortobagy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hortobagy
# ********************
#
# Retrieve city #238: gemena
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gemena
# ********************
#
# Retrieve city #239: arman
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=arman
# ********************
#
# Retrieve city #240: bar harbor
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bar harbor
# ********************
#
# Retrieve city #241: port lincoln
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port lincoln
# ********************
#
# Retrieve city #242: manadhoo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=manadhoo
# ********************
#
# Retrieve city #243: phan rang
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=phan rang
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #244: ilo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ilo
# ********************
#
# Retrieve city #245: manaure
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=manaure
# ********************
#
# Retrieve city #246: fairbanks
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=fairbanks
# ********************
#
# Retrieve city #247: bagojo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bagojo
# ********************
#
# Retrieve city #248: el alto
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=el alto
# ********************
#
# Retrieve city #249: thayetmyo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=thayetmyo
# ********************
#
# Retrieve city #250: brooks
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=brooks
# ********************
#
# Retrieve city #251: lakota
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lakota
# ********************
#
# Retrieve city #252: lichinga
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lichinga
# ********************
#
# Retrieve city #253: le vauclin
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=le vauclin
# ********************
#
# Retrieve city #254: mogzon
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mogzon
# ********************
#
# Retrieve city #255: bullhead city
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bullhead city
# ********************
#
# Retrieve city #256: noshiro
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=noshiro
# ********************
#
# Retrieve city #257: aquiraz
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=aquiraz
# ********************
#
# Retrieve city #258: faanui
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=faanui
# ********************
#
# Retrieve city #259: makakilo city
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=makakilo city
# ********************
#
# Retrieve city #260: noumea
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=noumea
# ********************
#
# Retrieve city #261: opochka
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=opochka
# ********************
#
# Retrieve city #262: palana
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=palana
# ********************
#
# Retrieve city #263: vaasa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaasa
# ********************
#
# Retrieve city #264: samalaeulu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=samalaeulu
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #265: yichang
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yichang
# ********************
#
# Retrieve city #266: montefiascone
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=montefiascone
# ********************
#
# Retrieve city #267: khorixas
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=khorixas
# ********************
#
# Retrieve city #268: kachikau
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kachikau
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #269: juigalpa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=juigalpa
# ********************
#
# Retrieve city #270: jutai
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=jutai
# ********************
#
# Retrieve city #271: kongolo
# ...
#
# Retrieve city #547: adelaide
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=adelaide
# ********************
#
# Retrieve city #548: hofn
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hofn
# ********************
#
# Retrieve city #549: san quintin
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=san quintin
# ********************
#
# Retrieve city #550: okato
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=okato
# ********************
#
# Retrieve city #551: esperance
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=esperance
# ********************
#
# Retrieve city #552: mamou
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mamou
# ********************
#
# Retrieve city #553: anuradhapura
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=anuradhapura
# ********************
#
# Retrieve city #554: galveston
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=galveston
# ********************
#
# Retrieve city #555: vaitape
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vaitape
# ********************
#
# Retrieve city #556: namibe
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=namibe
# ********************
#
# Retrieve city #557: itaituba
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=itaituba
# ********************
#
# Retrieve city #558: maragogi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=maragogi
# ********************
#
# Retrieve city #559: praia
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=praia
# ********************
#
# Retrieve city #560: kita
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kita
# ********************
#
# Retrieve city #561: sumbawa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sumbawa
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #562: yeniseysk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=yeniseysk
# ********************
#
# Retrieve city #563: nanortalik
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nanortalik
# ********************
#
# Retrieve city #564: belapatfalva
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=belapatfalva
# ********************
#
# Retrieve city #565: anastasiyevskaya
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=anastasiyevskaya
# ********************
#
# Retrieve city #566: lumphat
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lumphat
# ********************
#
# Retrieve city #567: tallahassee
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tallahassee
# ********************
#
# Retrieve city #568: talnakh
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=talnakh
# ********************
#
# Retrieve city #569: pandan
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pandan
# ********************
#
# Retrieve city #570: lodwar
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=lodwar
# ********************
#
# Retrieve city #571: raudeberg
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=raudeberg
# ********************
#
# Retrieve city #572: khandyga
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=khandyga
# ********************
#
# Retrieve city #573: pimenteiras
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pimenteiras
# ********************
#
# Retrieve city #574: erzin
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=erzin
# ********************
#
# Retrieve city #575: rapid valley
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=rapid valley
# ********************
#
# Retrieve city #576: riyadh
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=riyadh
# ********************
#
# Retrieve city #577: farafenni
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=farafenni
# ********************
#
# Retrieve city #578: korla
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=korla
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #579: clarence town
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=clarence town
# ********************
#
# Retrieve city #580: oranjemund
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=oranjemund
# ********************
#
# Retrieve city #581: kleck
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kleck
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #582: kawalu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=kawalu
# ********************
#
# Retrieve city #583: gambissara
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gambissara
# ********************
#
# Retrieve city #584: chicama
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chicama
# ********************
#
# Retrieve city #585: grand-santi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=grand-santi
# ********************
#
# Retrieve city #586: antofagasta
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=antofagasta
# ********************
#
# Retrieve city #587: urdzhar
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=urdzhar
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #588: nalut
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nalut
# ********************
#
# Retrieve city #589: vetlanda
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vetlanda
# ********************
#
# Retrieve city #590: tambovka
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tambovka
# ********************
#
# Retrieve city #591: palasa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=palasa
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #592: bucerias
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bucerias
# ********************
#
# Retrieve city #593: zagan
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zagan
# ********************
#
# Retrieve city #594: inirida
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=inirida
# ********************
#
# Retrieve city #595: verkhnevilyuysk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=verkhnevilyuysk
# ********************
#
# Retrieve city #596: qiongshan
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=qiongshan
# ********************
#
# Retrieve city #597: severo-kurilsk
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=severo-kurilsk
# ********************
#
# Retrieve city #598: alamosa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=alamosa
# ********************
#
# Retrieve city #599: wawa
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=wawa
# ********************
#
# Retrieve city #600: asau
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=asau
# Exception: Missing data point(s)
# ********************
#
# Pause: 30 seconds
#
# ********************
#
# Retrieve city #601: brigantine
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=brigantine
# ********************
#
# Retrieve city #602: sosnovo-ozerskoye
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=sosnovo-ozerskoye
# ********************
#
# Retrieve city #603: piacabucu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=piacabucu
# ********************
#
# Retrieve city #604: cowra
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=cowra
# ********************
#
# Retrieve city #605: ilhabela
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=ilhabela
# ********************
#
# Retrieve city #606: burley
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=burley
# ********************
#
# Retrieve city #607: xining
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=xining
# ********************
#
# Retrieve city #608: vir
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vir
# ********************
#
# Retrieve city #609: bossembele
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=bossembele
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #610: chaupal
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chaupal
# ********************
#
# Retrieve city #611: vestmannaeyjar
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=vestmannaeyjar
# ********************
#
# Retrieve city #612: chilca
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=chilca
# ********************
#
# Retrieve city #613: elizabeth city
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=elizabeth city
# ********************
#
# Retrieve city #614: menongue
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=menongue
# ********************
#
# Retrieve city #615: moncton
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=moncton
# ********************
#
# Retrieve city #616: zhezkazgan
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=zhezkazgan
# ********************
#
# Retrieve city #617: touros
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=touros
# ********************
#
# Retrieve city #618: tual
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=tual
# ********************
#
# Retrieve city #619: san jose
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=san jose
# ********************
#
# Retrieve city #620: north platte
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=north platte
# ********************
#
# Retrieve city #621: mizan teferi
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mizan teferi
# ********************
#
# Retrieve city #622: gilgit
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gilgit
# ********************
#
# Retrieve city #623: florianopolis
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=florianopolis
# ********************
#
# Retrieve city #624: diamantino
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=diamantino
# ********************
#
# Retrieve city #625: san mateo del mar
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=san mateo del mar
# ********************
#
# Retrieve city #626: umzimvubu
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=umzimvubu
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #627: borovoy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=borovoy
# ********************
#
# Retrieve city #628: gizo
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=gizo
# ********************
#
# Retrieve city #629: port macquarie
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=port macquarie
# ********************
#
# Retrieve city #630: moissala
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=moissala
# ********************
#
# Retrieve city #631: los llanos de aridane
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=los llanos de aridane
# ********************
#
# Retrieve city #632: santa cruz
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=santa cruz
# ********************
#
# Retrieve city #633: mwinilunga
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=mwinilunga
# ********************
#
# Retrieve city #634: hualahuises
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=hualahuises
# ********************
#
# Retrieve city #635: santa eulalia del rio
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=santa eulalia del rio
# Exception: Missing data point(s)
# ********************
#
# Retrieve city #636: pioner
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=pioner
# ********************
#
# Retrieve city #637: nortelandia
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=nortelandia
# ********************
#
# Retrieve city #638: krasnyy chikoy
# URL: http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=25bc90a1196e6f153eece0bc0b0fc9eb&q=krasnyy chikoy
# ********************
#
# Retrieval complete
#
# ********************

# %% [markdown]
# ## Data Cleaning

# %%
cities_df.head(20)
# Out:
#                     City Country          Date    Lat     Lng  \
# 0          belushya guba      ru           NaN    NaN     NaN
# 1                  vaini      to  1.532677e+09  15.34   74.49
# 2                  airai      pw  1.532677e+09  -8.93  125.41
# 3            grand haven      us  1.532676e+09  43.06  -86.23
# 4                 utiroa      ki           NaN    NaN     NaN
# 5                 albany      au  1.532675e+09  42.65  -73.75
# 6                ushuaia      ar  1.532675e+09 -54.81  -68.31
# 7              jamestown      sh  1.532677e+09 -33.21  138.60
# 8         port elizabeth      za  1.532676e+09  39.31  -74.98
# 9            san antonio      cl  1.532675e+09 -33.58  -71.61
# 10                  chuy      uy  1.532677e+09 -33.69  -53.46
# 11                atuona      pf  1.532677e+09  -9.80 -139.03
# 12                 mecca      sa  1.532675e+09  21.43   39.83
# 13            lavrentiya      ru  1.532677e+09  65.58 -170.99
# 14            moss point      us  1.532677e+09  30.41  -88.53
# 15                mantua      cu  1.532676e+09  45.16   10.79
# 16               zaoyang      cn  1.532678e+09  32.12  112.76
# 17          longyearbyen      sj  1.532676e+09  78.22   15.63
# 18  vila franca do campo      pt  1.532677e+09  37.72  -25.43
# 19             taolanaro      mg           NaN    NaN     NaN
#
#     Max Temperature (F)  Humidity  Cloudiness  Wind Speed
# 0                   NaN       NaN         NaN         NaN
# 1                 73.56     100.0        88.0        9.98
# 2                 78.60      56.0        20.0        1.14
# 3                 66.20     100.0         1.0       12.88
# 4                   NaN       NaN         NaN         NaN
# 5                 73.40      83.0        20.0        4.70
# 6                 50.00      18.0         0.0       20.80
# 7                 55.20      63.0        32.0       12.77
# 8                 75.20      94.0         1.0        6.17
# 9                 48.20      81.0        90.0        2.24
# 10                52.77      98.0        88.0       15.68
# 11                78.87     100.0        56.0       17.13
# 12               102.20      24.0         0.0        7.63
# 13                45.93      94.0        92.0        8.30
# 14                82.40     100.0        90.0        3.15
# 15                78.80      61.0         0.0        3.36
# 16                77.88     100.0        88.0        5.39
# 17                42.80      81.0        75.0       25.28
# 18                69.80      83.0        20.0       13.87
# 19                  NaN       NaN         NaN         NaN

# %%
#Check number of values for each column to see if we lost cities in the search 
print(f'\nColumn Counts:')
cities_df.count()
# Out:
# Column Counts:
# City                   638
# Country                638
# Date                   567
# Lat                    567
# Lng                    567
# Max Temperature (F)    567
# Humidity               567
# Cloudiness             567
# Wind Speed             567
# dtype: int64

# %%
#Drop columns with missing variables
cities_df = cities_df.dropna()
cities_df.head()
# Out:
#           City Country          Date    Lat     Lng  Max Temperature (F)  \
# 1        vaini      to  1.532677e+09  15.34   74.49                73.56
# 2        airai      pw  1.532677e+09  -8.93  125.41                78.60
# 3  grand haven      us  1.532676e+09  43.06  -86.23                66.20
# 5       albany      au  1.532675e+09  42.65  -73.75                73.40
# 6      ushuaia      ar  1.532675e+09 -54.81  -68.31                50.00
#
#    Humidity  Cloudiness  Wind Speed
# 1     100.0        88.0        9.98
# 2      56.0        20.0        1.14
# 3     100.0         1.0       12.88
# 5      83.0        20.0        4.70
# 6      18.0         0.0       20.80

# %%
#Convert "Date" to DATETIME
cities_df['Date'] = pd.to_datetime(cities_df['Date'], unit='s')
cities_df.head()
# Out:
#           City Country                Date    Lat     Lng  \
# 1        vaini      to 2018-07-27 07:35:51  15.34   74.49
# 2        airai      pw 2018-07-27 07:43:42  -8.93  125.41
# 3  grand haven      us 2018-07-27 07:17:00  43.06  -86.23
# 5       albany      au 2018-07-27 07:11:00  42.65  -73.75
# 6      ushuaia      ar 2018-07-27 07:00:00 -54.81  -68.31
#
#    Max Temperature (F)  Humidity  Cloudiness  Wind Speed
# 1                73.56     100.0        88.0        9.98
# 2                78.60      56.0        20.0        1.14
# 3                66.20     100.0         1.0       12.88
# 5                73.40      83.0        20.0        4.70
# 6                50.00      18.0         0.0       20.80

# %%
# Save Cities Data frame to an output csv file
cities_df.to_csv("Output/BP_Output_cities_df.csv", index = False)

# %% [markdown]
# ## Chart: Temperature (F) vs. Latitude Scatter Plot

# %%
cities_df.plot.scatter(["Lat"], ["Max Temperature (F)"], marker ='o', alpha = 1, grid = True)

# Chart details
plt.title("Termperature (F) v. City Latitude")
plt.xlabel("City Latitude")
plt.ylabel("Max Temp (F)")

# Save an image of the chart and print to screen
plt.savefig("Output/BP_Output_Temperature_vs_CityLatitude_ScatterPlot.png")
plt.show()

# %% [markdown]
# ## Chart: Humidity (%) vs. Latitude

# %%
cities_df.plot.scatter(["Lat"], ["Humidity"], marker ='o', alpha = 1, grid = True)

# Chart details
plt.title("Humidity v. City Latitude")
plt.xlabel("City Latitude")
plt.ylabel("Humidity")

# Save an image of the chart and print to screen
plt.savefig("Output/BP_Output_Humidity_vs_CityLatitude_ScatterPlot.png")
plt.show()

# %% [markdown]
# ## Chart: Cloudiness (%) vs. Latitude

# %%
cities_df.plot.scatter(["Lat"], ["Cloudiness"], marker ='o', alpha = 1, grid = True)

# Chart details
plt.title("Cloudiness v. City Latitude")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness")

# Save an image of the chart and print to screen
plt.savefig("Output/BP_Output_Cloudiness_vs_CityLatitude_ScatterPlot.png")
plt.show()

# %% [markdown]
# ## Chart: Wind Speed (mph) vs. Latitude

# %%
cities_df.plot.scatter(["Lat"], ["Wind Speed"], marker ='o', alpha = 1, grid = True)

# Chart details
plt.title("Wind Speed (MPH) v. City Latitude")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (MPH)")

# Save an image of the chart and print to screen
plt.savefig("Output/BP_Output_WindSpeedMPH_vs_CityLatitude_ScatterPlot.png")
plt.show()
